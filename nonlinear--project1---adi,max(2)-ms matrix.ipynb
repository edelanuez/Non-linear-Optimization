# %%
import cvxpy as cp 
import numpy as np
import pandas as pd
import os

# %%
#reading in files
model = pd.read_csv('model.csv')
target1 = pd.read_csv('target1.csv')
target2 = pd.read_csv('target2.csv')
target3 = pd.read_csv('target3.csv')

# %%
#making model c_dts just to make sure
model['constant'] = model['oas'] * model['oasd']* model['weight']
model.dropna(subset=['constant'], inplace=True)
#print(model['constant'])

# %%
##making target1 d_t vector
target1['d_t'] = target1['oas'] * target1['oasd']
target1.dropna(subset=['d_t'], inplace=True)
#print(target1['d_t'])

# %%
target1.dropna(subset=['s_Finance'],inplace=True)
model.dropna(subset=['s_Finance'],inplace=True)

# %%
###pandas into numpy array
constant_array = model['constant'].values
d_t_array = target1['d_t'].values
MS_M11_array=model['s_Finance'].values
MS_T11_array=target1['s_Finance'].values

# %%
#tranposed array
transposed_dt = np.transpose(d_t_array)
transposed_dt.shape
# Out:
# (558,)

# %%
w = cp.Variable(558)
obj = cp.Minimize(cp.norm(constant_array @ MS_M11_array - cp.matmul(MS_T11_array, w.T), 2))
constraints = [w <= 0.3, cp.sum(w) == 1]
problem = cp.Problem(obj, constraints)
result = problem.solve(verbose=True,solver=cp.SCS) ####scs is a first-order solver that uses an iterative splitting technique when just solving the whole thing is too expensive
#print("Optimal value:", result)
#print("Optimal weights:", w.value.round(decimals=2))
#print("Optimal value", problem.solve)
#print(w.value.round(decimals=2))
#print("Optimal value", problem.solve(verbose=True))
# Out:
# ...
#                                      CVXPY
#                                      v1.3.0
# ...
# (CVXPY) Apr 20 09:00:18 AM: Your problem has 558 variables, 2 constraints, and 0 parameters.
# (CVXPY) Apr 20 09:00:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 20 09:00:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 20 09:00:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 20 09:00:18 AM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 20 09:00:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 20 09:00:18 AM: Applying reduction Dcp2Cone
# ...

# %%
#print("Optimal objective value:", result)
#print("Optimal variable values:")
# Out:
# [0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
#  0.00179211 0.00179211 0.00179211 0.00179211 0.00179211 0.00179211
# ...

# %%
###second column
target1.dropna(subset=['s_Industrial'],inplace=True)
model.dropna(subset=['s_Industrial'],inplace=True)

###pandas into numpy array
constant_array = model['constant'].values
d_t_array = target1['d_t'].values
MS_M12_array=model['s_Industrial'].values
MS_T12_array=target1['s_Industrial'].values

# %%
#tranposed array
transposed_dt = np.transpose(d_t_array)
transposed_dt.shape
# Out:
# (558,)

# %%
w = cp.Variable(558)
obj = cp.Minimize(cp.norm(constant_array @ MS_M12_array - cp.matmul(MS_T12_array, w.T), 2))
constraints = [w <= 0.3, cp.sum(w) == 1]
problem = cp.Problem(obj, constraints)
result = problem.solve(verbose=True,solver=cp.SCS) ####scs i
# Out:
# ...
#                                      CVXPY
#                                      v1.3.0
# ...
# (CVXPY) Apr 20 09:04:55 AM: Your problem has 558 variables, 2 constraints, and 0 parameters.
# (CVXPY) Apr 20 09:04:55 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 20 09:04:55 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 20 09:04:55 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 20 09:04:55 AM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 20 09:04:55 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 20 09:04:55 AM: Applying reduction Dcp2Cone
# ...

# %%
###third column
target1.dropna(subset=['s_Utility'],inplace=True)
model.dropna(subset=['s_Utility'],inplace=True)

# %%
###pandas into numpy array
constant_array = model['constant'].values
d_t_array = target1['d_t'].values
MS_M13_array=model['s_Utility'].values
MS_T13_array=target1['s_Utility'].values

# %%
#tranposed array
transposed_dt = np.transpose(d_t_array)
transposed_dt.shape
# Out:
# (558,)

# %%
w = cp.Variable(558)
obj = cp.Minimize(cp.norm(constant_array @ MS_M13_array - cp.matmul(MS_T13_array, w.T), 2))
constraints = [w <= 0.3, cp.sum(w) == 1]
problem = cp.Problem(obj, constraints)
result = problem.solve(verbose=True,solver=cp.SCS) ####scs i
# Out:
# ...
#                                      CVXPY
#                                      v1.3.0
# ...
# (CVXPY) Apr 20 02:28:15 PM: Your problem has 558 variables, 2 constraints, and 0 parameters.
# (CVXPY) Apr 20 02:28:15 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 20 02:28:15 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 20 02:28:15 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 20 02:28:15 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 20 02:28:15 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 20 02:28:15 PM: Applying reduction Dcp2Cone
# ...

# %%
# Out:
# [-0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804  0.29999999 -0.01102804 -0.01102804 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804  0.29999999
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804  0.29999999 -0.01102804
#  -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804 -0.01102804
# ...

# %%
###fourth column
target1.dropna(subset=['s_Securitized'],inplace=True)
model.dropna(subset=['s_Securitized'],inplace=True)

# %%
###pandas into numpy array
constant_array = model['constant'].values
d_t_array = target1['d_t'].values
MS_M14_array=model['s_Securitized'].values
MS_T14_array=target1['s_Securitized'].values

# %%
#tranposed array
transposed_dt = np.transpose(d_t_array)
transposed_dt.shape
# Out:
# (558,)

# %%
w = cp.Variable(558)
obj = cp.Minimize(cp.norm(constant_array @ MS_M14_array - cp.matmul(MS_T14_array, w.T), 2))
constraints = [w <= 0.3, cp.sum(w) == 1]
problem = cp.Problem(obj, constraints)
result = problem.solve(verbose=True,solver=cp.SCS) ####scs i
# Out:
# ...
#                                      CVXPY
#                                      v1.3.0
# ...
# (CVXPY) Apr 20 09:11:45 AM: Your problem has 558 variables, 2 constraints, and 0 parameters.
# (CVXPY) Apr 20 09:11:45 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 20 09:11:45 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 20 09:11:45 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 20 09:11:45 AM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 20 09:11:45 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 20 09:11:45 AM: Applying reduction Dcp2Cone
# ...

# %%
###fifth column
target1.dropna(subset=['s_Municipal'],inplace=True)
model.dropna(subset=['s_Municipal'],inplace=True)

# %%
###pandas into numpy array
constant_array = model['constant'].values
d_t_array = target1['d_t'].values
MS_M15_array=model['s_Municipal'].values
MS_T15_array=target1['s_Municipal'].values

# %%
#tranposed array
transposed_dt = np.transpose(d_t_array)
transposed_dt.shape
# Out:
# (558,)

# %%
w = cp.Variable(558)
obj = cp.Minimize(cp.norm(constant_array @ MS_M15_array - cp.matmul(MS_T15_array, w.T), 2))
constraints = [w <= 0.3, cp.sum(w) == 1]
problem = cp.Problem(obj, constraints)
result = problem.solve(verbose=True,solver=cp.SCS) ####scs i
# Out:
# ...
#                                      CVXPY
#                                      v1.3.0
# ...
# (CVXPY) Apr 20 09:15:28 AM: Your problem has 558 variables, 2 constraints, and 0 parameters.
# (CVXPY) Apr 20 09:15:28 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 20 09:15:28 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 20 09:15:28 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 20 09:15:28 AM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 20 09:15:28 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 20 09:15:28 AM: Applying reduction Dcp2Cone
# ...

# %%
###sixth column
target1.dropna(subset=['s_Government'],inplace=True)
model.dropna(subset=['s_Government'],inplace=True)

# %%
###pandas into numpy array
constant_array = model['constant'].values
d_t_array = target1['d_t'].values
MS_M16_array=model['s_Government'].values
MS_T16_array=target1['s_Government'].values

# %%
#tranposed array
transposed_dt = np.transpose(d_t_array)
transposed_dt.shape
# Out:
# (558,)

# %%
w = cp.Variable(558)
obj = cp.Minimize(cp.norm(constant_array @ MS_M16_array - cp.matmul(MS_T16_array, w.T), 2))
constraints = [w <= 0.3, cp.sum(w) == 1]
problem = cp.Problem(obj, constraints)
result = problem.solve(verbose=True,solver=cp.SCS) ####scs i
# Out:
# ...
#                                      CVXPY
#                                      v1.3.0
# ...
# (CVXPY) Apr 20 09:17:06 AM: Your problem has 558 variables, 2 constraints, and 0 parameters.
# (CVXPY) Apr 20 09:17:06 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 20 09:17:06 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 20 09:17:06 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 20 09:17:06 AM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 20 09:17:06 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 20 09:17:06 AM: Applying reduction Dcp2Cone
# ...

# %%
###sixth column
target1.dropna(subset=['s_Cash'],inplace=True)
model.dropna(subset=['s_Cash'],inplace=True)

# %%
###pandas into numpy array
constant_array = model['constant'].values
d_t_array = target1['d_t'].values
MS_M17_array=model['s_Cash'].values
MS_T17_array=target1['s_Cash'].values

# %%
#tranposed array
transposed_dt = np.transpose(d_t_array)
transposed_dt.shape
# Out:
# (558,)

# %%
w = cp.Variable(558)
obj = cp.Minimize(cp.norm(constant_array @ MS_M17_array - cp.matmul(MS_T17_array, w.T), 2))
constraints = [w <= 0.3, cp.sum(w) == 1]
problem = cp.Problem(obj, constraints)
result = problem.solve(verbose=True,solver=cp.SCS) ####scs i
# Out:
# ...
#                                      CVXPY
#                                      v1.3.0
# ...
# (CVXPY) Apr 20 09:18:41 AM: Your problem has 558 variables, 2 constraints, and 0 parameters.
# (CVXPY) Apr 20 09:18:41 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 20 09:18:41 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 20 09:18:41 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 20 09:18:41 AM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 20 09:18:41 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 20 09:18:41 AM: Applying reduction Dcp2Cone
# ...
